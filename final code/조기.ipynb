# %%
import selenium
from selenium import webdriver
from urllib.parse import quote
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import string
import matplotlib.pyplot as plt
# %matplotlib inline
import platform
from scipy.stats import *
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows': 
    # 윈도우   
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
data = pd.read_csv('./final/조기.csv')

# %%
data.head()
# Out:
#        어종  산지   규격   포장 수량   중량     낙찰고가     낙찰저가      평균가          일시
# 0  (선)백조기  기타  NaN  NaN  2  1.0   20,000   20,000   20,000  2000.01.03
# 1  (선)백조기  제주  NaN  NaN  6  1.0   10,000   10,000   10,000  2000.01.03
# 2  (선)수조기  목포  NaN  NaN  1  1.0   40,000   40,000   40,000  2000.01.03
# 3   (선)조기  인천  NaN  NaN  8  1.0   45,000   35,000   40,000  2000.01.03
# 4   (선)조기  기타  NaN  NaN  2  1.0  400,000  400,000  400,000  2000.01.03

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71483 entries, 0 to 71482
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   어종      71483 non-null  object
#  1   산지      71481 non-null  object
#  2   규격      61774 non-null  object
#  3   포장      61774 non-null  object
#  4   수량      71483 non-null  object
#  5   중량      71483 non-null  float64
#  6   낙찰고가    71483 non-null  object
#  7   낙찰저가    71483 non-null  object
#  8   평균가     71483 non-null  object
#  9   일시      71483 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 5.5+ MB

# %%
data =data.drop(['규격','포장'], axis=1)

# %%
data['수량'] = data['수량'].str.replace(',','')

# %%
data['수량'] = data['수량'].astype({'수량':float})

# %%
data['평균가'] = data['평균가'].str.replace(',','')
data['평균가'] = data['평균가'].astype(float)

# %%
data['qty'] = data['수량']*data['중량']

# %%
data_f = data.drop(['수량', '중량','낙찰고가','낙찰저가'], axis=1)

# %%
data_f
# Out:
#            어종      산지       평균가          일시    qty
# 0      (선)백조기      기타   20000.0  2000.01.03    2.0
# 1      (선)백조기      제주   10000.0  2000.01.03    6.0
# 2      (선)수조기      목포   40000.0  2000.01.03    1.0
# 3       (선)조기      인천   40000.0  2000.01.03    8.0
# 4       (선)조기      기타  400000.0  2000.01.03    2.0
# ...       ...     ...       ...         ...    ...
# 71478  (선)백조기  부산(기장)   80000.0  2021.04.01   40.0
# 71479  (선)수조기     제주도   65000.0  2021.04.01   40.0
# 71480  (선)참조기     제주도  294000.0  2021.04.01    4.2
# 71481  (선)참조기     제주도  476000.0  2021.04.01    6.8
# 71482  (선)참조기     제주도  296700.0  2021.04.01  140.0
#
# [71483 rows x 5 columns]

# %%
data_f.columns = ['species','from','평균가','date','qty']

# %%
data_f['1kg price'] = (data_f['평균가']/data['중량']).round(2)

# %%
data_f = data_f.drop(['평균가'],axis=1)
data_f
# Out:
#       species    from        date    qty  1kg price
# 0      (선)백조기      기타  2000.01.03    2.0    20000.0
# 1      (선)백조기      제주  2000.01.03    6.0    10000.0
# 2      (선)수조기      목포  2000.01.03    1.0    40000.0
# 3       (선)조기      인천  2000.01.03    8.0    40000.0
# 4       (선)조기      기타  2000.01.03    2.0   400000.0
# ...       ...     ...         ...    ...        ...
# 71478  (선)백조기  부산(기장)  2021.04.01   40.0     4000.0
# 71479  (선)수조기     제주도  2021.04.01   40.0     3250.0
# 71480  (선)참조기     제주도  2021.04.01    4.2    70000.0
# 71481  (선)참조기     제주도  2021.04.01    6.8    70000.0
# 71482  (선)참조기     제주도  2021.04.01  140.0    14835.0
#
# [71483 rows x 5 columns]

# %%
data_f.groupby(['species']).sum().sort_values('qty',ascending=False).round(1).head(10)
# Out:
#                 qty    1kg price
# species
# (선)참조기    5686758.9  331811698.0
# (냉)조기     4299638.2   42163253.7
# (냉)조기 기타  3299146.9   18357779.8
# (선)백조기    2076841.1  107031817.7
# (냉)참조기    1319863.7   52331873.6
# (선)조기      591871.3  151492760.2
# (선)수조기     121327.1   46036896.7
# (냉)수조기     105797.0     679726.9
# (냉)백조기      74575.5     611864.0
# (활)수조기       2390.5     871400.0

# %%
grouped = data_f.groupby('species')
species = grouped.agg({'qty': 'sum', '1kg price' : 'mean'}).round(2)

# %%
species.sort_values('qty',ascending=False)
# Out:
#                 qty  1kg price
# species
# (선)참조기    5686758.9   18406.37
# (냉)조기     4299638.2    5208.56
# (냉)조기 기타  3299146.9    4510.51
# (선)백조기    2076841.1    3695.98
# (냉)참조기    1319863.7   14082.85
# (선)조기      591871.3   36495.49
# (선)수조기     121327.1   11729.15
# (냉)수조기     105797.0    3146.88
# (냉)백조기      74575.5    3059.32
# (활)수조기       2390.5    8299.05
# (활)참조기        691.0   10470.66
# (냉건)백조기       430.0    1250.00
# (선)조기 기타      343.5    4714.29

# %%
index_g = data_f[(data_f['species']=='(선)조기 기타') | (data_f['species']=='(냉건)백조기')
                 |(data_f['species']=='(활)참조기')|(data_f['species']=='(활)수조기')].index

# %%
index_g2 = data_f[(data_f['species']=='(냉)백조기') | (data_f['species']=='(냉)수조기')].index

# %%
index_g3 = data_f[(data_f['species']=='(선)수조기') | (data_f['species']=='(선)조기')].index

# %%
len(index_g3)
# Out:
# 8076

# %%
data_f = data_f.drop(index_g3,axis=0)

# %%
data_f.shape
# Out:
# (62867, 5)

# %%
grouped = data_f.groupby('species')
species = grouped.agg({'qty': 'sum', '1kg price' : 'mean'}).round(2)
species.sort_values('qty',ascending=False)
# Out:
#                 qty  1kg price
# species
# (선)참조기    5686758.9   18406.37
# (냉)조기     4299638.2    5208.56
# (냉)조기 기타  3299146.9    4510.51
# (선)백조기    2076841.1    3695.98
# (냉)참조기    1319863.7   14082.85

# %%
grouped = data_ff.groupby('from')
origin = grouped.agg({'qty': 'sum', '1kg price' : 'mean'}).round(2)

# %%
pd.set_option('display.max_row', 500)

# %%
origin.sort_values('qty',ascending=False).tail(33)
# Out:
#                                    qty  1kg price
# from
# 미국                              1289.0   25875.00
# 기타(수입)                          1000.0    4630.00
# 벌교                               865.0     944.44
# 세네갈                              800.0    5000.00
# 서산                               759.5    7061.33
# 포항                               729.0   22010.30
# 속초                               453.0    8882.78
# (원양)라스팔마스                        450.0    3333.33
# 베트남                              434.0   19920.64
# 기타(원양)                           390.0     653.84
# 멕시코                              360.0    1666.67
# 이란                               350.0    2500.00
# 아르메니아                            300.0    4520.00
# 노르웨이                             232.5    2533.33
# CONGO. THE DEMOCRATIC REPUBLIC   200.0    6250.00
# 콩고                               188.0    2500.00
# 아르헨티나                            186.0    3333.33
# 구룡포                              170.0     411.76
# 죽변                               124.0   12000.00
# 동해시                              122.0   28625.00
# 감포                               108.0   11440.00
# 임원                               104.0   19500.00
# 인도양                              100.0    3000.00
# 스페인                              100.0    1250.00
# 거문도                               92.0   22708.33
# 순천                                62.0    2750.00
# 삼척                                61.0    7500.00
# 태국                                40.0    2000.00
# 라스팔마스                             30.0    2000.00
# 인도                                30.0    4000.00
# 축산                                27.0   15192.31
# 필리핀                               21.0   10000.00
# 거진                                15.0    7500.00

# %%
index_g = data_f[(data_f['from']=='소래') | (data_f['from']=='고성')
                 |(data_f['from']=='포클랜드')|(data_f['from']=='안면도')].index
data_ff = data_f.drop(index_g,axis=0)
data_f.shape, data_ff.shape
# Out:
# ((62867, 5), (62862, 5))

# %%
a = origin[origin['qty']<200000].index
test1 = pd.DataFrame()
for i in a.values :
    test = data_ff[data_ff['from'] == i]
    test1 = test1.append(test)

# %%
a
# Out:
# Index(['(원양)라스팔마스', '(원양)러시아', '(원양)인도네시아', 'CONGO. THE DEMOCRATIC REPUBLIC',
#        '감포', '거문도', '거제도', '거진', '격포', '고흥', '구룡포', '군산', '기타', '기타(국내)',
#        '기타(수입)', '기타(원양)', '남해', '노르웨이', '대만', '대천', '동해시', '라스팔마스', '러시아',
#        '마산', '멕시코', '미국', '방어진', '벌교', '베트남', '보령', '부산', '부안', '사천', '삼척',
#        '서산', '서천', '세네갈', '속초', '순천', '스페인', '신안', '아르메니아', '아르헨티나', '안흥',
#        '영광', '완도', '이란', '인도', '인도네시아', '인도양', '인천', '일본', '임원', '장항', '제주',
#        '죽변', '진도', '축산', '충무', '콩고', '태국', '태안', '태평양', '통영', '포항', '필리핀',
#        '흑산도'],
#       dtype='object', name='from')

# %%
len(test1['from'].unique())
# Out:
# 67

# %%
test1.index
# Out:
# Int64Index([42882, 42883, 13813, 17168, 17507, 18231, 18233, 18912, 20301,
#             23648,
#             ...
#              8494,  8794,  9305, 24889, 35991,  4047, 28221, 28223, 37943,
#             59763],
#            dtype='int64', length=8611)

# %%
test = data_ff.drop(test1.index, axis=0)

# %%
test.groupby(['from']).sum().sort_values('qty',ascending=False)
# Out:
#                qty     1kg price
# from
# 중국      7455049.40  1.130880e+08
# 제주도     4184254.82  2.409812e+08
# 목포      1504515.30  3.137328e+07
# 나로도      537988.50  1.441642e+07
# 부산(기장)   481051.30  8.109723e+06
# 삼천포      426504.30  1.434819e+07
# (원양)중국   395778.50  1.504205e+06
# 여수       391855.88  1.073798e+07
# 추자도      300671.40  2.813745e+06

# %%
len(data_ff), len(test)
# Out:
# (62862, 54251)

# %%
grouped2 = test.groupby('from')
origin2 = grouped2.agg({'qty': 'sum', '1kg price' : 'mean'}).round(2)
origin2.sort_values('qty', ascending=False)
# Out:
#                qty  1kg price
# from
# 중국      7455049.40    8932.70
# 제주도     4184254.82   13812.19
# 목포      1504515.30    6758.57
# 나로도      537988.50    1708.71
# 부산(기장)   481051.30    3775.48
# 삼천포      426504.30    3180.01
# (원양)중국   395778.50    3380.24
# 여수       391855.88    3437.25
# 추자도      300671.40    3369.75

# %%
test = test.drop(9283,axis=0)

# %%
test['year'] = test['date'].str.split('.').str.get(0)
test['month'] = test['date'].str.split('.').str.get(1)
test['day'] = test['date'].str.split('.').str.get(2)

# %%
test[(test['from']=='(원양)중국')]
# Out:
#         species    from        date      qty  1kg price  year month day
# 10783     (냉)조기  (원양)중국  2006.07.31    440.0    2500.00  2006    07  31
# 11261     (냉)조기  (원양)중국  2006.09.26     16.0    7500.00  2006    09  26
# 11262     (냉)조기  (원양)중국  2006.09.26     56.0   16250.00  2006    09  26
# 11362    (냉)참조기  (원양)중국  2006.10.02     96.0     833.33  2006    10  02
# 13050     (냉)조기  (원양)중국  2007.03.17     80.0    6250.00  2007    03  17
# 13051     (냉)조기  (원양)중국  2007.03.17    800.0    1250.00  2007    03  17
# 13060     (냉)조기  (원양)중국  2007.03.19   1000.0    3000.00  2007    03  19
# 13070     (냉)조기  (원양)중국  2007.03.20   1152.0    2500.00  2007    03  20
# 13071     (냉)조기  (원양)중국  2007.03.20     80.0   14375.00  2007    03  20
# 13073     (냉)조기  (원양)중국  2007.03.20    800.0    2562.50  2007    03  20
# 13075     (냉)조기  (원양)중국  2007.03.20    400.0    1500.00  2007    03  20
# 13091     (냉)조기  (원양)중국  2007.03.21    240.0    3087.50  2007    03  21
# 13108     (냉)조기  (원양)중국  2007.03.22    240.0    2500.00  2007    03  22
# 13110     (냉)조기  (원양)중국  2007.03.22   2400.0    4125.00  2007    03  22
# 13114     (냉)조기  (원양)중국  2007.03.22    325.0    1538.46  2007    03  22
# 13116     (냉)조기  (원양)중국  2007.03.22    400.0    1450.00  2007    03  22
# 13125     (냉)조기  (원양)중국  2007.03.23    530.0    2050.00  2007    03  23
# 13126     (냉)조기  (원양)중국  2007.03.23   1500.0    1190.00  2007    03  23
# 13127     (냉)조기  (원양)중국  2007.03.23   1100.0    3140.00  2007    03  23
# 13136     (냉)조기  (원양)중국  2007.03.24    450.0    1288.89  2007    03  24
# 13137     (냉)조기  (원양)중국  2007.03.24    720.0    3333.33  2007    03  24
# 13155     (냉)조기  (원양)중국  2007.03.26   1269.0    1333.33  2007    03  26
# 13168     (냉)조기  (원양)중국  2007.03.27   1350.0    1111.11  2007    03  27
# 13170     (냉)조기  (원양)중국  2007.03.27    540.0    3333.33  2007    03  27
# 13172     (냉)조기  (원양)중국  2007.03.27    180.0    2222.22  2007    03  27
# 13181     (냉)조기  (원양)중국  2007.03.28    588.0    5242.86  2007    03  28
# 13182     (냉)조기  (원양)중국  2007.03.28    630.0    5877.78  2007    03  28
# 13193     (냉)조기  (원양)중국  2007.03.29    325.0    1538.46  2007    03  29
# 13195     (냉)조기  (원양)중국  2007.03.29    990.0    1366.67  2007    03  29
# 13196     (냉)조기  (원양)중국  2007.03.29    900.0    3333.33  2007    03  29
# 13210     (냉)조기  (원양)중국  2007.03.30    270.0    1333.33  2007    03  30
# 13212     (냉)조기  (원양)중국  2007.03.30    180.0    1777.78  2007    03  30
# 13219     (냉)조기  (원양)중국  2007.03.31    630.0    2600.00  2007    03  31
# 13229     (냉)조기  (원양)중국  2007.04.02    180.0   13333.33  2007    04  02
# 13231     (냉)조기  (원양)중국  2007.04.02    180.0    3333.33  2007    04  02
# 13235     (냉)조기  (원양)중국  2007.04.02    180.0    2222.22  2007    04  02
# 13240     (냉)조기  (원양)중국  2007.04.03    350.0    1428.57  2007    04  03
# 13242     (냉)조기  (원양)중국  2007.04.03   1520.0    2287.50  2007    04  03
# 13244     (냉)조기  (원양)중국  2007.04.03   1440.0    3375.00  2007    04  03
# 13245     (냉)조기  (원양)중국  2007.04.03    495.0    3000.00  2007    04  03
# 13247     (냉)조기  (원양)중국  2007.04.03     70.0    4285.71  2007    04  03
# 13249     (냉)조기  (원양)중국  2007.04.03    350.0    2571.43  2007    04  03
# 13258     (냉)조기  (원양)중국  2007.04.04    720.0    2637.50  2007    04  04
# 13259     (냉)조기  (원양)중국  2007.04.04    749.0    3142.86  2007    04  04
# 13260     (냉)조기  (원양)중국  2007.04.04   1280.0    1825.00  2007    04  04
# 13261     (냉)조기  (원양)중국  2007.04.04   1200.0    1512.50  2007    04  04
# 13274     (냉)조기  (원양)중국  2007.04.05    880.0    2125.00  2007    04  05
# 13275     (냉)조기  (원양)중국  2007.04.05     80.0    3125.00  2007    04  05
# 13277     (냉)조기  (원양)중국  2007.04.05    300.0    2900.00  2007    04  05
# 13278     (냉)조기  (원양)중국  2007.04.05   2000.0    1287.50  2007    04  05
# 13291     (냉)조기  (원양)중국  2007.04.06    448.0    3750.00  2007    04  06
# 13292     (냉)조기  (원양)중국  2007.04.06    320.0    1512.50  2007    04  06
# 13293     (냉)조기  (원양)중국  2007.04.06   1440.0    2537.50  2007    04  06
# 13309     (냉)조기  (원양)중국  2007.04.07    420.0    2385.71  2007    04  07
# 13310     (냉)조기  (원양)중국  2007.04.07    140.0    3071.43  2007    04  07
# 13314     (냉)조기  (원양)중국  2007.04.07    400.0    1250.00  2007    04  07
# 13329     (냉)조기  (원양)중국  2007.04.09    400.0    3750.00  2007    04  09
# 13331     (냉)조기  (원양)중국  2007.04.09    160.0    2500.00  2007    04  09
# 13347     (냉)조기  (원양)중국  2007.04.10    880.0    2525.00  2007    04  10
# 13350     (냉)조기  (원양)중국  2007.04.10    300.0    2900.00  2007    04  10
# 13358     (냉)조기  (원양)중국  2007.04.11   1280.0    1500.00  2007    04  11
# 13360     (냉)조기  (원양)중국  2007.04.11   1960.0    3775.00  2007    04  11
# 13362     (냉)조기  (원양)중국  2007.04.11    800.0    2337.50  2007    04  11
# 13373     (냉)조기  (원양)중국  2007.04.12    160.0    1250.00  2007    04  12
# 13374     (냉)조기  (원양)중국  2007.04.12    450.0    3333.33  2007    04  12
# 13376     (냉)조기  (원양)중국  2007.04.12    400.0    2625.00  2007    04  12
# 13384     (냉)조기  (원양)중국  2007.04.13    400.0    2500.00  2007    04  13
# 13385     (냉)조기  (원양)중국  2007.04.13    400.0    1450.00  2007    04  13
# 13391     (냉)조기  (원양)중국  2007.04.14    800.0    2175.00  2007    04  14
# 13392     (냉)조기  (원양)중국  2007.04.14    840.0    3700.00  2007    04  14
# 13393     (냉)조기  (원양)중국  2007.04.14    400.0    1587.50  2007    04  14
# 13394     (냉)조기  (원양)중국  2007.04.14    400.0    1450.00  2007    04  14
# 13407     (냉)조기  (원양)중국  2007.04.16     97.5    3230.77  2007    04  16
# 13408     (냉)조기  (원양)중국  2007.04.16    390.0    4615.38  2007    04  16
# 13411     (냉)조기  (원양)중국  2007.04.16    715.0    1846.15  2007    04  16
# 13425     (냉)조기  (원양)중국  2007.04.17    480.0    2500.00  2007    04  17
# 13428     (냉)조기  (원양)중국  2007.04.17     75.0    1533.33  2007    04  17
# 13432     (냉)조기  (원양)중국  2007.04.17    800.0    1500.00  2007    04  17
# 13441     (냉)조기  (원양)중국  2007.04.18   1600.0    2475.00  2007    04  18
# 13442     (냉)조기  (원양)중국  2007.04.18    800.0    3750.00  2007    04  18
# 13443     (냉)조기  (원양)중국  2007.04.18    800.0    1500.00  2007    04  18
# 13454     (냉)조기  (원양)중국  2007.04.19   1350.0    2000.00  2007    04  19
# 13457     (냉)조기  (원양)중국  2007.04.19   1050.0    5257.14  2007    04  19
# 13458     (냉)조기  (원양)중국  2007.04.19   2656.0    2025.00  2007    04  19
# 13462     (냉)조기  (원양)중국  2007.04.19   1400.0    1857.14  2007    04  19
# 13475     (냉)조기  (원양)중국  2007.04.20    464.0    2500.00  2007    04  20
# 13476     (냉)조기  (원양)중국  2007.04.20    720.0    3750.00  2007    04  20
# 13479     (냉)조기  (원양)중국  2007.04.20   1280.0    2275.00  2007    04  20
# 13488     (냉)조기  (원양)중국  2007.04.21    400.0    2250.00  2007    04  21
# 13489     (냉)조기  (원양)중국  2007.04.21    720.0    3750.00  2007    04  21
# 13497     (냉)조기  (원양)중국  2007.04.23    480.0    3750.00  2007    04  23
# 13501     (냉)조기  (원양)중국  2007.04.23    480.0    1875.00  2007    04  23
# 13507     (냉)조기  (원양)중국  2007.04.24    800.0    2500.00  2007    04  24
# 13509     (냉)조기  (원양)중국  2007.04.24   2800.0    3387.50  2007    04  24
# 13513     (냉)조기  (원양)중국  2007.04.24   1750.0    2400.00  2007    04  24
# 13515     (냉)조기  (원양)중국  2007.04.24   1680.0    1550.00  2007    04  24
# 13528     (냉)조기  (원양)중국  2007.04.25   1200.0    3750.00  2007    04  25
# 13538     (냉)조기  (원양)중국  2007.04.26    480.0    3750.00  2007    04  26
# 13539     (냉)조기  (원양)중국  2007.04.26    160.0    5625.00  2007    04  26
# 13540     (냉)조기  (원양)중국  2007.04.26     70.0    3142.86  2007    04  26
# 13542     (냉)조기  (원양)중국  2007.04.26    300.0    3000.00  2007    04  26
# 13543     (냉)조기  (원양)중국  2007.04.26    800.0    1562.50  2007    04  26
# 13552     (냉)조기  (원양)중국  2007.04.27   1040.0    2500.00  2007    04  27
# 13553     (냉)조기  (원양)중국  2007.04.27   1600.0    3750.00  2007    04  27
# 13556     (냉)조기  (원양)중국  2007.04.27    400.0    1312.50  2007    04  27
# 13561     (냉)조기  (원양)중국  2007.04.28    700.0    1714.29  2007    04  28
# 13562     (냉)조기  (원양)중국  2007.04.28    150.0    2666.67  2007    04  28
# 13563     (냉)조기  (원양)중국  2007.04.28    366.0    6032.79  2007    04  28
# 13564     (냉)조기  (원양)중국  2007.04.28    700.0    4285.71  2007    04  28
# 13565     (냉)조기  (원양)중국  2007.04.28    700.0    3157.14  2007    04  28
# 13566     (냉)조기  (원양)중국  2007.04.28    122.0    4229.51  2007    04  28
# 13577     (냉)조기  (원양)중국  2007.04.30    140.0    2857.14  2007    04  30
# 13578     (냉)조기  (원양)중국  2007.04.30   1050.0    2142.86  2007    04  30
# 13579     (냉)조기  (원양)중국  2007.04.30   3440.0    3025.00  2007    04  30
# 13599     (냉)조기  (원양)중국  2007.05.01     40.0    1875.00  2007    05  01
# 13601     (냉)조기  (원양)중국  2007.05.01    735.0    2871.43  2007    05  01
# 13603     (냉)조기  (원양)중국  2007.05.01   2877.0    4142.86  2007    05  01
# 13609     (냉)조기  (원양)중국  2007.05.01    576.0    3762.50  2007    05  01
# 13610     (냉)조기  (원양)중국  2007.05.01    325.0    3800.00  2007    05  01
# 13611     (냉)조기  (원양)중국  2007.05.01    440.0    2525.00  2007    05  01
# 13628     (냉)조기  (원양)중국  2007.05.02     70.0    3142.86  2007    05  02
# 13635     (냉)조기  (원양)중국  2007.05.03   1050.0    1514.29  2007    05  03
# 13637     (냉)조기  (원양)중국  2007.05.03    800.0    4000.00  2007    05  03
# 13639     (냉)조기  (원양)중국  2007.05.03    336.0    7142.86  2007    05  03
# 13640     (냉)조기  (원양)중국  2007.05.03   1330.0    4285.71  2007    05  03
# 13643     (냉)조기  (원양)중국  2007.05.03   1050.0    2571.43  2007    05  03
# 13647     (냉)조기  (원양)중국  2007.05.04    560.0    1614.29  2007    05  04
# 13648     (냉)조기  (원양)중국  2007.05.04    400.0    4137.50  2007    05  04
# 13652     (냉)조기  (원양)중국  2007.05.04     65.0    1846.15  2007    05  04
# 13653     (냉)조기  (원양)중국  2007.05.04    350.0    2857.14  2007    05  04
# 13659     (냉)조기  (원양)중국  2007.05.05    490.0    2857.14  2007    05  05
# 13660     (냉)조기  (원양)중국  2007.05.05    840.0    2071.43  2007    05  05
# 13661     (냉)조기  (원양)중국  2007.05.05    130.0    1615.38  2007    05  05
# 13663     (냉)조기  (원양)중국  2007.05.05   1050.0    4485.71  2007    05  05
# 13664     (냉)조기  (원양)중국  2007.05.05    280.0    7142.86  2007    05  05
# 13665     (냉)조기  (원양)중국  2007.05.05    400.0    1500.00  2007    05  05
# 13667     (냉)조기  (원양)중국  2007.05.05    650.0    5492.31  2007    05  05
# 13682     (냉)조기  (원양)중국  2007.05.08    490.0    3028.57  2007    05  08
# 13685     (냉)조기  (원양)중국  2007.05.08    400.0    3750.00  2007    05  08
# 13688     (냉)조기  (원양)중국  2007.05.08    130.0    5092.31  2007    05  08
# 13690     (냉)조기  (원양)중국  2007.05.08    490.0    2014.29  2007    05  08
# 13691     (냉)조기  (원양)중국  2007.05.08    400.0    1250.00  2007    05  08
# 13696     (냉)조기  (원양)중국  2007.05.09    400.0    2562.50  2007    05  09
# 13697     (냉)조기  (원양)중국  2007.05.09    400.0    4137.50  2007    05  09
# 13699     (냉)조기  (원양)중국  2007.05.09   1183.0    4285.71  2007    05  09
# 13701     (냉)조기  (원양)중국  2007.05.09    210.0    2785.71  2007    05  09
# 13705     (냉)조기  (원양)중국  2007.05.10   1050.0    3257.14  2007    05  10
# 13706     (냉)조기  (원양)중국  2007.05.10    325.0    3153.85  2007    05  10
# 13709     (냉)조기  (원양)중국  2007.05.10   1547.0    4171.43  2007    05  10
# 13713     (냉)조기  (원양)중국  2007.05.10    600.0    5666.67  2007    05  10
# 13714     (냉)조기  (원양)중국  2007.05.10    840.0    1728.57  2007    05  10
# 13722     (냉)조기  (원양)중국  2007.05.11    140.0    2285.71  2007    05  11
# 13727     (냉)조기  (원양)중국  2007.05.11    560.0    2857.14  2007    05  11
# 13729     (냉)조기  (원양)중국  2007.05.11    240.0    1500.00  2007    05  11
# 13733     (냉)조기  (원양)중국  2007.05.12    210.0    1714.29  2007    05  12
# 13734     (냉)조기  (원양)중국  2007.05.12    400.0    4137.50  2007    05  12
# 13735     (냉)조기  (원양)중국  2007.05.12    350.0    4285.71  2007    05  12
# 13744     (냉)조기  (원양)중국  2007.05.14    400.0    2500.00  2007    05  14
# 13745     (냉)조기  (원양)중국  2007.05.14    400.0    2500.00  2007    05  14
# 13756     (냉)조기  (원양)중국  2007.05.15   1540.0    1828.57  2007    05  15
# 13758     (냉)조기  (원양)중국  2007.05.15   1820.0    4357.14  2007    05  15
# 13760     (냉)조기  (원양)중국  2007.05.15    490.0    2585.71  2007    05  15
# 13768     (냉)조기  (원양)중국  2007.05.16    565.5    5415.38  2007    05  16
# 13769     (냉)조기  (원양)중국  2007.05.16    700.0    2857.14  2007    05  16
# 13770     (냉)조기  (원양)중국  2007.05.16    400.0    2125.00  2007    05  16
# 13771     (냉)조기  (원양)중국  2007.05.16   1330.0    2585.71  2007    05  16
# 13774     (냉)조기  (원양)중국  2007.05.16   1400.0    4285.71  2007    05  16
# 13775     (냉)조기  (원양)중국  2007.05.16   3850.0    4528.57  2007    05  16
# 13778     (냉)조기  (원양)중국  2007.05.16   1540.0    2471.43  2007    05  16
# 13787     (냉)조기  (원양)중국  2007.05.17     57.0    2456.14  2007    05  17
# 13788     (냉)조기  (원양)중국  2007.05.17    700.0    1614.29  2007    05  17
# 13790     (냉)조기  (원양)중국  2007.05.17    700.0    4285.71  2007    05  17
# 13802     (냉)조기  (원양)중국  2007.05.18   1750.0    1628.57  2007    05  18
# 13805     (냉)조기  (원양)중국  2007.05.18   7490.0    4485.71  2007    05  18
# 13808     (냉)조기  (원양)중국  2007.05.18   1050.0    2428.57  2007    05  18
# 13815     (냉)조기  (원양)중국  2007.05.19   1050.0    4728.57  2007    05  19
# 13818     (냉)조기  (원양)중국  2007.05.19    140.0    2142.86  2007    05  19
# 13826     (냉)조기  (원양)중국  2007.05.21   1099.0    1957.14  2007    05  21
# 13828     (냉)조기  (원양)중국  2007.05.21    700.0    4728.57  2007    05  21
# 13830     (냉)조기  (원양)중국  2007.05.21    350.0    2928.57  2007    05  21
# 13836     (냉)조기  (원양)중국  2007.05.22    350.0    1814.29  2007    05  22
# 13838     (냉)조기  (원양)중국  2007.05.22    240.0    2500.00  2007    05  22
# 13839     (냉)조기  (원양)중국  2007.05.22    800.0    3750.00  2007    05  22
# 13841     (냉)조기  (원양)중국  2007.05.22   1050.0    4728.57  2007    05  22
# 13843     (냉)조기  (원양)중국  2007.05.22   4550.0    3385.71  2007    05  22
# 13844     (냉)조기  (원양)중국  2007.05.22    240.0    1500.00  2007    05  22
# 13849     (냉)조기  (원양)중국  2007.05.23    455.0    3307.69  2007    05  23
# 13851     (냉)조기  (원양)중국  2007.05.23    350.0    1500.00  2007    05  23
# 13853     (냉)조기  (원양)중국  2007.05.23    400.0    3750.00  2007    05  23
# 13855     (냉)조기  (원양)중국  2007.05.23   2940.0    4271.43  2007    05  23
# 13857     (냉)조기  (원양)중국  2007.05.23    350.0    2571.43  2007    05  23
# 13863     (냉)조기  (원양)중국  2007.05.24    280.0    1714.29  2007    05  24
# 13866     (냉)조기  (원양)중국  2007.05.24   1040.0    1987.50  2007    05  24
# 13867     (냉)조기  (원양)중국  2007.05.24    640.0    3450.00  2007    05  24
# 13868     (냉)조기  (원양)중국  2007.05.24    192.0    5625.00  2007    05  24
# 13870     (냉)조기  (원양)중국  2007.05.24    700.0    4728.57  2007    05  24
# 13871     (냉)조기  (원양)중국  2007.05.24   1820.0    2428.57  2007    05  24
# 13872     (냉)조기  (원양)중국  2007.05.24   1448.0    1612.50  2007    05  24
# 13889     (냉)조기  (원양)중국  2007.05.26    700.0    2928.57  2007    05  26
# 13891     (냉)조기  (원양)중국  2007.05.26    140.0    6428.57  2007    05  26
# 13892     (냉)조기  (원양)중국  2007.05.26    427.0    4918.03  2007    05  26
# 13895     (냉)조기  (원양)중국  2007.05.26    315.0    4761.90  2007    05  26
# 13896     (냉)조기  (원양)중국  2007.05.26    650.0    5661.54  2007    05  26
# 13906     (냉)조기  (원양)중국  2007.05.28    325.0    4307.69  2007    05  28
# 13910     (냉)조기  (원양)중국  2007.05.28   1050.0    2885.71  2007    05  28
# 13923     (냉)조기  (원양)중국  2007.05.29   1050.0    1928.57  2007    05  29
# 13928     (냉)조기  (원양)중국  2007.05.29   1050.0    4000.00  2007    05  29
# 13932     (냉)조기  (원양)중국  2007.05.29    400.0    3550.00  2007    05  29
# 13935     (냉)조기  (원양)중국  2007.05.29    400.0    1500.00  2007    05  29
# 13941     (냉)조기  (원양)중국  2007.05.30    325.0    5661.54  2007    05  30
# 13944     (냉)조기  (원양)중국  2007.05.30    280.0    2678.57  2007    05  30
# 13946     (냉)조기  (원양)중국  2007.05.30   1890.0    4128.57  2007    05  30
# 13949     (냉)조기  (원양)중국  2007.05.30    700.0    2428.57  2007    05  30
# 13957     (냉)조기  (원양)중국  2007.05.31   1400.0    1857.14  2007    05  31
# 13960     (냉)조기  (원양)중국  2007.05.31    210.0    6428.57  2007    05  31
# 13961     (냉)조기  (원양)중국  2007.05.31    140.0    4428.57  2007    05  31
# 13964     (냉)조기  (원양)중국  2007.05.31    350.0    2485.71  2007    05  31
# 13973     (냉)조기  (원양)중국  2007.06.01    350.0    1428.57  2007    06  01
# 13977     (냉)조기  (원양)중국  2007.06.01   1470.0    4342.86  2007    06  01
# 13984     (냉)조기  (원양)중국  2007.06.02    325.0    5569.23  2007    06  02
# 13987     (냉)조기  (원양)중국  2007.06.02    371.0    6428.57  2007    06  02
# 13989     (냉)조기  (원양)중국  2007.06.02   1400.0    2428.57  2007    06  02
# 14003     (냉)조기  (원양)중국  2007.06.04    325.0    5584.62  2007    06  04
# 14004     (냉)조기  (원양)중국  2007.06.04    700.0    4285.71  2007    06  04
# 14019     (냉)조기  (원양)중국  2007.06.05    750.0    2206.67  2007    06  05
# 14020     (냉)조기  (원양)중국  2007.06.05    140.0    6428.57  2007    06  05
# 14021     (냉)조기  (원양)중국  2007.06.05    700.0    4000.00  2007    06  05
# 14027     (냉)조기  (원양)중국  2007.06.06    325.0    2676.92  2007    06  06
# 14028     (냉)조기  (원양)중국  2007.06.06   1400.0    1571.43  2007    06  06
# 14030     (냉)조기  (원양)중국  2007.06.06    300.0    4166.67  2007    06  06
# 14032     (냉)조기  (원양)중국  2007.06.06    210.0    3571.43  2007    06  06
# 14033     (냉)조기  (원양)중국  2007.06.06   1680.0    2228.57  2007    06  06
# 14035     (냉)조기  (원양)중국  2007.06.06    300.0    1750.00  2007    06  06
# 14056     (냉)조기  (원양)중국  2007.06.08   8750.0    2514.29  2007    06  08
# 14057     (냉)조기  (원양)중국  2007.06.08   1540.0    4157.14  2007    06  08
# 14059     (냉)조기  (원양)중국  2007.06.08    325.0    5415.38  2007    06  08
# 14060     (냉)조기  (원양)중국  2007.06.08   4200.0    1328.57  2007    06  08
# 14071     (냉)조기  (원양)중국  2007.06.09    210.0    2857.14  2007    06  09
# 14073     (냉)조기  (원양)중국  2007.06.09     45.0   16666.67  2007    06  09
# 14074     (냉)조기  (원양)중국  2007.06.09   1400.0    4000.00  2007    06  09
# 14076     (냉)조기  (원양)중국  2007.06.09    840.0    1714.29  2007    06  09
# 14077     (냉)조기  (원양)중국  2007.06.09    330.0    1924.24  2007    06  09
# 14078     (냉)조기  (원양)중국  2007.06.09   1600.0    3500.00  2007    06  09
# 14079     (냉)조기  (원양)중국  2007.06.09     29.0   17241.38  2007    06  09
# 14080     (냉)조기  (원양)중국  2007.06.09    300.0    1750.00  2007    06  09
# 14089     (냉)조기  (원양)중국  2007.06.11    130.0    3800.00  2007    06  11
# 14091     (냉)조기  (원양)중국  2007.06.11    630.0    4761.90  2007    06  11
# 14092     (냉)조기  (원양)중국  2007.06.11    210.0    2285.71  2007    06  11
# 14102     (냉)조기  (원양)중국  2007.06.12    700.0    1714.29  2007    06  12
# 14104     (냉)조기  (원양)중국  2007.06.12    325.0    5415.38  2007    06  12
# 14105     (냉)조기  (원양)중국  2007.06.12   1190.0    2857.14  2007    06  12
# 14115     (냉)조기  (원양)중국  2007.06.13    350.0    4500.00  2007    06  13
# 14117     (냉)조기  (원양)중국  2007.06.13    350.0    2928.57  2007    06  13
# 14126     (냉)조기  (원양)중국  2007.06.14    210.0    1428.57  2007    06  14
# 14130     (냉)조기  (원양)중국  2007.06.14    770.0    4000.00  2007    06  14
# 14136     (냉)조기  (원양)중국  2007.06.15    900.0    2633.33  2007    06  15
# 14138     (냉)조기  (원양)중국  2007.06.15    240.0    4166.67  2007    06  15
# 14139     (냉)조기  (원양)중국  2007.06.15   1050.0    4000.00  2007    06  15
# 14141     (냉)조기  (원양)중국  2007.06.15    270.0    1750.00  2007    06  15
# 14144     (냉)조기  (원양)중국  2007.06.15   9425.0    2246.15  2007    06  15
# 14157     (냉)조기  (원양)중국  2007.06.16    240.0    2500.00  2007    06  16
# 14162     (냉)조기  (원양)중국  2007.06.16    300.0    4166.67  2007    06  16
# 14165     (냉)조기  (원양)중국  2007.06.16    325.0    5415.38  2007    06  16
# 14167     (냉)조기  (원양)중국  2007.06.16    300.0    1666.67  2007    06  16
# 14215     (냉)조기  (원양)중국  2007.06.22    350.0    4500.00  2007    06  22
# 14217     (냉)조기  (원양)중국  2007.06.22    130.0    3076.92  2007    06  22
# 14219     (냉)조기  (원양)중국  2007.06.22    650.0    4615.38  2007    06  22
# 14220     (냉)조기  (원양)중국  2007.06.22   1050.0    1642.86  2007    06  22
# 14221     (냉)조기  (원양)중국  2007.06.22    700.0    2671.43  2007    06  22
# 14226     (냉)조기  (원양)중국  2007.06.23    630.0    4444.44  2007    06  23
# 14227     (냉)조기  (원양)중국  2007.06.23    700.0    4300.00  2007    06  23
# 14238     (냉)조기  (원양)중국  2007.06.25    350.0    2928.57  2007    06  25
# 14242     (냉)조기  (원양)중국  2007.06.25   2100.0    1528.57  2007    06  25
# 14257     (냉)조기  (원양)중국  2007.06.26   1400.0    2914.29  2007    06  26
# 14261     (냉)조기  (원양)중국  2007.06.26    700.0    4500.00  2007    06  26
# 14263     (냉)조기  (원양)중국  2007.06.26    840.0    1714.29  2007    06  26
# 14275     (냉)조기  (원양)중국  2007.06.27    448.0    1714.29  2007    06  27
# 14278     (냉)조기  (원양)중국  2007.06.27   1050.0    4242.86  2007    06  27
# 14291     (냉)조기  (원양)중국  2007.06.28   2086.0    3642.86  2007    06  28
# 14293     (냉)조기  (원양)중국  2007.06.28   1400.0    2257.14  2007    06  28
# 14305     (냉)조기  (원양)중국  2007.06.29   1400.0    1771.43  2007    06  29
# 14306     (냉)조기  (원양)중국  2007.06.29    364.0    4714.29  2007    06  29
# 14309     (냉)조기  (원양)중국  2007.06.29   1750.0    2600.00  2007    06  29
# 14318     (냉)조기  (원양)중국  2007.06.30     35.0    1714.29  2007    06  30
# 14319     (냉)조기  (원양)중국  2007.06.30   1950.0    4938.46  2007    06  30
# 14322     (냉)조기  (원양)중국  2007.06.30    350.0    4000.00  2007    06  30
# 14323     (냉)조기  (원양)중국  2007.06.30    105.0    3528.57  2007    06  30
# 14331     (냉)조기  (원양)중국  2007.07.02     21.0    1500.00  2007    07  02
# 14345     (냉)조기  (원양)중국  2007.07.03    350.0    2928.57  2007    07  03
# 14349     (냉)조기  (원양)중국  2007.07.03   1050.0    1714.29  2007    07  03
# 14350     (냉)조기  (원양)중국  2007.07.03   1625.0    3000.00  2007    07  03
# 14358     (냉)조기  (원양)중국  2007.07.04    924.0    1714.29  2007    07  04
# 14360     (냉)조기  (원양)중국  2007.07.04    700.0    4000.00  2007    07  04
# 14363     (냉)조기  (원양)중국  2007.07.04    196.0    2857.14  2007    07  04
# 14371     (냉)조기  (원양)중국  2007.07.05    560.0    2871.43  2007    07  05
# 14375     (냉)조기  (원양)중국  2007.07.05    350.0    4000.00  2007    07  05
# 14378     (냉)조기  (원양)중국  2007.07.05    350.0    1500.00  2007    07  05
# 14386     (냉)조기  (원양)중국  2007.07.06    350.0    2485.71  2007    07  06
# 14388     (냉)조기  (원양)중국  2007.07.06    280.0    4300.00  2007    07  06
# 14389     (냉)조기  (원양)중국  2007.07.06    140.0    7142.86  2007    07  06
# 14392     (냉)조기  (원양)중국  2007.07.06   1950.0    3692.31  2007    07  06
# 14393     (냉)조기  (원양)중국  2007.07.06    875.0    1985.71  2007    07  06
# 14394     (냉)조기  (원양)중국  2007.07.06    130.0    2769.23  2007    07  06
# 14396     (냉)조기  (원양)중국  2007.07.06    180.0    2666.67  2007    07  06
# 14407     (냉)조기  (원양)중국  2007.07.07    210.0    1714.29  2007    07  07
# 14410     (냉)조기  (원양)중국  2007.07.07    350.0    4585.71  2007    07  07
# 14411     (냉)조기  (원양)중국  2007.07.07    770.0    2600.00  2007    07  07
# 14419     (냉)조기  (원양)중국  2007.07.09    350.0    1500.00  2007    07  09
# 14420     (냉)조기  (원양)중국  2007.07.09    160.0    2500.00  2007    07  09
# 14425     (냉)조기  (원양)중국  2007.07.09    350.0    2485.71  2007    07  09
# 14430     (냉)조기  (원양)중국  2007.07.10    650.0    2461.54  2007    07  10
# 14431     (냉)조기  (원양)중국  2007.07.10   3640.0    1428.57  2007    07  10
# 14432     (냉)조기  (원양)중국  2007.07.10    975.0    7692.31  2007    07  10
# 14436     (냉)조기  (원양)중국  2007.07.10   1400.0    4000.00  2007    07  10
# 14438     (냉)조기  (원양)중국  2007.07.10    650.0    1538.46  2007    07  10
# 14439     (냉)조기  (원양)중국  2007.07.10   4200.0    2314.29  2007    07  10
# 14450     (냉)조기  (원양)중국  2007.07.11   1750.0    4000.00  2007    07  11
# 14452     (냉)조기  (원양)중국  2007.07.11    350.0    2571.43  2007    07  11
# 14454     (냉)조기  (원양)중국  2007.07.11    140.0    2857.14  2007    07  11
# 14461     (냉)조기  (원양)중국  2007.07.12     80.0    3412.50  2007    07  12
# 14464     (냉)조기  (원양)중국  2007.07.12    140.0    7142.86  2007    07  12
# 14469     (냉)조기  (원양)중국  2007.07.13    540.0    4383.33  2007    07  13
# 14472     (냉)조기  (원양)중국  2007.07.13   1400.0    4371.43  2007    07  13
# 14475     (냉)조기  (원양)중국  2007.07.13    700.0    2571.43  2007    07  13
# 14477     (냉)조기  (원양)중국  2007.07.13    300.0    1333.33  2007    07  13
# 14486     (냉)조기  (원양)중국  2007.07.14    700.0    1428.57  2007    07  14
# 14489     (냉)조기  (원양)중국  2007.07.14    325.0    5092.31  2007    07  14
# 14491     (냉)조기  (원양)중국  2007.07.14    210.0    4285.71  2007    07  14
# 14503     (냉)조기  (원양)중국  2007.07.16   4674.0    5433.33  2007    07  16
# 14505     (냉)조기  (원양)중국  2007.07.16   1050.0    1657.14  2007    07  16
# 14514     (냉)조기  (원양)중국  2007.07.17    350.0    4285.71  2007    07  17
# 14515     (냉)조기  (원양)중국  2007.07.17    350.0    2928.57  2007    07  17
# 14539     (냉)조기  (원양)중국  2007.07.19     58.5    2769.23  2007    07  19
# 14540     (냉)조기  (원양)중국  2007.07.19   1036.0    1714.29  2007    07  19
# 14542     (냉)조기  (원양)중국  2007.07.19   6825.0    3369.23  2007    07  19
# 14545     (냉)조기  (원양)중국  2007.07.19    700.0    3000.00  2007    07  19
# 14556     (냉)조기  (원양)중국  2007.07.20    350.0    1514.29  2007    07  20
# 14558     (냉)조기  (원양)중국  2007.07.20    140.0    8571.43  2007    07  20
# 14559     (냉)조기  (원양)중국  2007.07.20   9310.0    1985.71  2007    07  20
# 14568     (냉)조기  (원양)중국  2007.07.21    350.0    1814.29  2007    07  21
# 14569     (냉)조기  (원양)중국  2007.07.21    160.0    2500.00  2007    07  21
# 14571     (냉)조기  (원양)중국  2007.07.21   1050.0    2714.29  2007    07  21
# 14572     (냉)조기  (원양)중국  2007.07.21   1280.0    1500.00  2007    07  21
# 14573     (냉)조기  (원양)중국  2007.07.21    900.0    2000.00  2007    07  21
# 14579     (냉)조기  (원양)중국  2007.07.23    560.0    3500.00  2007    07  23
# 14580     (냉)조기  (원양)중국  2007.07.23    630.0    4444.44  2007    07  23
# 14581     (냉)조기  (원양)중국  2007.07.23    700.0    2857.14  2007    07  23
# 14590     (냉)조기  (원양)중국  2007.07.24    350.0    1814.29  2007    07  24
# 14591     (냉)조기  (원양)중국  2007.07.24     70.0   21428.57  2007    07  24
# 14593     (냉)조기  (원양)중국  2007.07.24    140.0    7142.86  2007    07  24
# 14594     (냉)조기  (원양)중국  2007.07.24   1750.0    4057.14  2007    07  24
# 14595     (냉)조기  (원양)중국  2007.07.24    840.0    2857.14  2007    07  24
# 14602     (냉)조기  (원양)중국  2007.07.25    325.0    3400.00  2007    07  25
# 14604     (냉)조기  (원양)중국  2007.07.25   2030.0    4100.00  2007    07  25
# 14607     (냉)조기  (원양)중국  2007.07.25    350.0    2285.71  2007    07  25
# 14616     (냉)조기  (원양)중국  2007.07.26    350.0    1500.00  2007    07  26
# 14618     (냉)조기  (원양)중국  2007.07.26   1120.0    4085.71  2007    07  26
# 14627     (냉)조기  (원양)중국  2007.07.27   2268.0    1671.43  2007    07  27
# 14629     (냉)조기  (원양)중국  2007.07.27    350.0    4871.43  2007    07  27
# 14630     (냉)조기  (원양)중국  2007.07.27   1050.0    2542.86  2007    07  27
# 14635     (냉)조기  (원양)중국  2007.07.28    700.0    4000.00  2007    07  28
# 14636     (냉)조기  (원양)중국  2007.07.28    700.0    2571.43  2007    07  28
# 14645     (냉)조기  (원양)중국  2007.07.30    350.0    1814.29  2007    07  30
# 14647     (냉)조기  (원양)중국  2007.07.30   5852.0    4371.43  2007    07  30
# 14660     (냉)조기  (원양)중국  2007.07.31    350.0    4728.57  2007    07  31
# 14661     (냉)조기  (원양)중국  2007.07.31    104.0    2250.00  2007    07  31
# 14700     (냉)조기  (원양)중국  2007.08.06    210.0    1714.29  2007    08  06
# 14701     (냉)조기  (원양)중국  2007.08.06    350.0    2857.14  2007    08  06
# 14711     (냉)조기  (원양)중국  2007.08.07    140.0    1428.57  2007    08  07
# 14713     (냉)조기  (원양)중국  2007.08.07   2450.0    4042.86  2007    08  07
# 14714     (냉)조기  (원양)중국  2007.08.07    210.0    3385.71  2007    08  07
# 14725     (냉)조기  (원양)중국  2007.08.08  25250.0      31.68  2007    08  08
# 14727     (냉)조기  (원양)중국  2007.08.08    350.0    4128.57  2007    08  08
# 14728     (냉)조기  (원양)중국  2007.08.08    300.0    2116.67  2007    08  08
# 14734     (냉)조기  (원양)중국  2007.08.09   1316.0    4000.00  2007    08  09
# 14741     (냉)조기  (원양)중국  2007.08.10    350.0    1428.57  2007    08  10
# 14743     (냉)조기  (원양)중국  2007.08.10   3500.0    4000.00  2007    08  10
# 14744     (냉)조기  (원양)중국  2007.08.10   1050.0    2357.14  2007    08  10
# 14753     (냉)조기  (원양)중국  2007.08.11    300.0    4166.67  2007    08  11
# 14755     (냉)조기  (원양)중국  2007.08.11    700.0    2571.43  2007    08  11
# 14756     (냉)조기  (원양)중국  2007.08.11    600.0    1666.67  2007    08  11
# 14757     (냉)조기  (원양)중국  2007.08.11   3000.0    2083.33  2007    08  11
# 14775     (냉)조기  (원양)중국  2007.08.13    700.0    4000.00  2007    08  13
# 14777     (냉)조기  (원양)중국  2007.08.13    700.0    2485.71  2007    08  13
# 14803     (냉)조기  (원양)중국  2007.08.14    325.0    3646.15  2007    08  14
# 14805     (냉)조기  (원양)중국  2007.08.14    195.0    2030.77  2007    08  14
# 14824     (냉)조기  (원양)중국  2007.08.15    600.0    3000.00  2007    08  15
# 14825     (냉)조기  (원양)중국  2007.08.15   2450.0    4057.14  2007    08  15
# 14828     (냉)조기  (원양)중국  2007.08.15    700.0    1500.00  2007    08  15
# 14829     (냉)조기  (원양)중국  2007.08.15    600.0    2000.00  2007    08  15
# 14842     (냉)조기  (원양)중국  2007.08.16    371.0    4885.71  2007    08  16
# 14856     (냉)조기  (원양)중국  2007.08.17    210.0    3714.29  2007    08  17
# 14861  (냉)조기 기타  (원양)중국  2007.08.17    100.0    4500.00  2007    08  17
# 14862  (냉)조기 기타  (원양)중국  2007.08.17    100.0    4000.00  2007    08  17
# 14863  (냉)조기 기타  (원양)중국  2007.08.17    100.0    5000.00  2007    08  17
# 14869     (냉)조기  (원양)중국  2007.08.18    180.0   16666.67  2007    08  18
# 14871     (냉)조기  (원양)중국  2007.08.18    600.0    4666.67  2007    08  18
# 14873     (냉)조기  (원양)중국  2007.08.18    360.0    3416.67  2007    08  18
# 14881     (냉)조기  (원양)중국  2007.08.20   1320.0    4516.67  2007    08  20
# 14882     (냉)조기  (원양)중국  2007.08.20    120.0    8333.33  2007    08  20
# 14884     (냉)조기  (원양)중국  2007.08.20    360.0    1750.00  2007    08  20
# 14893     (냉)조기  (원양)중국  2007.08.21    270.0    2555.56  2007    08  21
# 14894     (냉)조기  (원양)중국  2007.08.21    180.0    4444.44  2007    08  21
# 14895     (냉)조기  (원양)중국  2007.08.21   1200.0    3066.67  2007    08  21
# 14896     (냉)조기  (원양)중국  2007.08.21    702.0    8333.33  2007    08  21
# 14897     (냉)조기  (원양)중국  2007.08.21    360.0    2000.00  2007    08  21
# 14898     (냉)조기  (원양)중국  2007.08.21   2220.0    4183.33  2007    08  21
# 14910     (냉)조기  (원양)중국  2007.08.22   1400.0    3285.71  2007    08  22
# 14911     (냉)조기  (원양)중국  2007.08.22    300.0    5516.67  2007    08  22
# 14912     (냉)조기  (원양)중국  2007.08.22    325.0    2030.77  2007    08  22
# 14920     (냉)조기  (원양)중국  2007.08.23    180.0    5516.67  2007    08  23
# 14922     (냉)조기  (원양)중국  2007.08.23   1400.0    3857.14  2007    08  23
# 14934     (냉)조기  (원양)중국  2007.08.24   1140.0    4916.67  2007    08  24
# 14935     (냉)조기  (원양)중국  2007.08.24     60.0   10000.00  2007    08  24
# 14937     (냉)조기  (원양)중국  2007.08.24    540.0    3216.67  2007    08  24
# 14947     (냉)조기  (원양)중국  2007.08.25    180.0   16666.67  2007    08  25
# 14948     (냉)조기  (원양)중국  2007.08.25    325.0    2769.23  2007    08  25
# 14949     (냉)조기  (원양)중국  2007.08.25    325.0    4307.69  2007    08  25
# 14950     (냉)조기  (원양)중국  2007.08.25    300.0    4733.33  2007    08  25
# 14953     (냉)조기  (원양)중국  2007.08.25    300.0    2900.00  2007    08  25
# 14968     (냉)조기  (원양)중국  2007.08.27   2610.0    3400.00  2007    08  27
# 14978     (냉)조기  (원양)중국  2007.08.28    300.0    2900.00  2007    08  28
# 14994     (냉)조기  (원양)중국  2007.08.29    120.0    2000.00  2007    08  29
# 14997     (냉)조기  (원양)중국  2007.08.29    600.0    4666.67  2007    08  29
# 14998     (냉)조기  (원양)중국  2007.08.29    240.0    1666.67  2007    08  29
# 14999     (냉)조기  (원양)중국  2007.08.29    600.0    2000.00  2007    08  29
# 15013     (냉)조기  (원양)중국  2007.08.30     60.0    3333.33  2007    08  30
# 15014     (냉)조기  (원양)중국  2007.08.30    325.0    1230.77  2007    08  30
# 15015     (냉)조기  (원양)중국  2007.08.30    300.0    5516.67  2007    08  30
# 15019     (냉)조기  (원양)중국  2007.08.30    300.0    2000.00  2007    08  30
# 15035     (냉)조기  (원양)중국  2007.08.31   3450.0    3450.00  2007    08  31
# 15038     (냉)조기  (원양)중국  2007.08.31    900.0    2033.33  2007    08  31
# 15052     (냉)조기  (원양)중국  2007.09.01    600.0    4666.67  2007    09  01
# 15053     (냉)조기  (원양)중국  2007.09.01    900.0    2000.00  2007    09  01
# 15139     (냉)조기  (원양)중국  2007.09.07    500.0    2540.00  2007    09  07
# 15140     (냉)조기  (원양)중국  2007.09.07    420.0    5066.67  2007    09  07
# 15141     (냉)조기  (원양)중국  2007.09.07   1200.0    2833.33  2007    09  07
# 15165     (냉)조기  (원양)중국  2007.09.08    600.0    1750.00  2007    09  08
# 15587     (냉)조기  (원양)중국  2007.10.05    100.0    1300.00  2007    10  05
# 18027     (냉)조기  (원양)중국  2008.04.05    650.0    1230.77  2008    04  05
# 18160    (냉)참조기  (원양)중국  2008.04.12    300.0    1666.67  2008    04  12
# 18161    (냉)참조기  (원양)중국  2008.04.12    700.0    1142.86  2008    04  12
# 18392     (냉)조기  (원양)중국  2008.05.01   1400.0    2571.43  2008    05  01
# 18701     (냉)조기  (원양)중국  2008.05.28    600.0    3000.00  2008    05  28
# 21094     (냉)조기  (원양)중국  2009.01.02     36.0    8333.33  2009    01  02

# %%
test[(test['from']=='중국')].groupby('species').sum()
# Out:
#                 qty    1kg price
# species
# (냉)조기     3183657.2  35437159.65
# (냉)조기 기타  3237593.9  18014461.48
# (냉)참조기     511391.9  32686606.72
# (선)백조기        856.4    398974.99
# (선)참조기     521550.0  26550800.00

# %%
china = test[(test['from']=='중국')]

# %%
test[(test['from']=='중국')].index
# Out:
# Int64Index([   13,    24,    34,    44,    55,    63,    70,    75,    83,
#                91,
#             ...
#             71310, 71311, 71346, 71348, 71349, 71357, 71386, 71417, 71426,
#             71447],
#            dtype='int64', length=12660)

# %%
test
# Out:
#       species    from        date    qty  1kg price  year month day
# 7      (선)백조기      목포  2000.01.04    1.0    10000.0  2000    01  04
# 13     (냉)참조기      중국  2000.01.04  130.0    23500.0  2000    01  04
# 24     (냉)참조기      중국  2000.01.05  140.0    21800.0  2000    01  05
# 26     (선)백조기      목포  2000.01.06   30.0    17000.0  2000    01  06
# 34     (냉)참조기      중국  2000.01.06  225.0    27800.0  2000    01  06
# ...       ...     ...         ...    ...        ...   ...   ...  ..
# 71477  (선)참조기     제주도  2021.03.31    2.1    65000.0  2021    03  31
# 71478  (선)백조기  부산(기장)  2021.04.01   40.0     4000.0  2021    04  01
# 71480  (선)참조기     제주도  2021.04.01    4.2    70000.0  2021    04  01
# 71481  (선)참조기     제주도  2021.04.01    6.8    70000.0  2021    04  01
# 71482  (선)참조기     제주도  2021.04.01  140.0    14835.0  2021    04  01
#
# [54250 rows x 8 columns]

# %%
a = test[test['from']=='중국'].index

# %%
a
# Out:
# Int64Index([   13,    24,    34,    44,    55,    63,    70,    75,    83,
#                91,
#             ...
#             71310, 71311, 71346, 71348, 71349, 71357, 71386, 71417, 71426,
#             71447],
#            dtype='int64', length=12660)

# %%
china_exc = test.drop(a,axis=0)

# %%
china_exc.groupby('from').sum()
# Out:
#                qty     1kg price
# from
# (원양)중국   395778.50  1.504205e+06
# 나로도      537988.50  1.441642e+07
# 목포      1504515.30  3.137328e+07
# 부산(기장)   481051.30  8.109723e+06
# 삼천포      426504.30  1.434819e+07
# 여수       391855.88  1.073798e+07
# 제주도     4184254.82  2.409812e+08
# 추자도      300671.40  2.813745e+06

# %%
china
# Out:
#       species from        date    qty  1kg price  year month day
# 13     (냉)참조기   중국  2000.01.04  130.0   23500.00  2000    01  04
# 24     (냉)참조기   중국  2000.01.05  140.0   21800.00  2000    01  05
# 34     (냉)참조기   중국  2000.01.06  225.0   27800.00  2000    01  06
# 44     (냉)참조기   중국  2000.01.07  220.0   28400.00  2000    01  07
# 55     (냉)참조기   중국  2000.01.08  444.0   29100.00  2000    01  08
# ...       ...  ...         ...    ...        ...   ...   ...  ..
# 71357   (냉)조기   중국  2021.03.12   80.0    7150.00  2021    03  12
# 71386   (냉)조기   중국  2021.03.16  180.0    2972.22  2021    03  16
# 71417   (냉)조기   중국  2021.03.19   80.0    5675.00  2021    03  19
# 71426   (냉)조기   중국  2021.03.20  400.0    4775.00  2021    03  20
# 71447   (냉)조기   중국  2021.03.26  180.0    4777.78  2021    03  26
#
# [12660 rows x 8 columns]

# %%
grouped = china.groupby('species')
origin = grouped.agg({'qty': 'sum', '1kg price' : 'mean'}).round(2)
origin
# Out:
#                 qty  1kg price
# species
# (냉)조기     3183657.2    5422.67
# (냉)조기 기타  3237593.9    4601.40
# (냉)참조기     511391.9   25576.37
# (선)백조기        856.4   11734.56
# (선)참조기     521550.0   29566.59

# %%
china = china.drop(china[china['species']=='(선)백조기'].index,axis=0)

# %%
china[china['1kg price']>100000].index
# Out:
# Int64Index([990, 3031], dtype='int64')

# %%
china = china.drop(china[china['1kg price']>100000].index,axis=0)

# %%
t = [china[china['species']=='(냉)조기']['1kg price'],china[china['species']=='(냉)조기 기타']['1kg price'],china[china['species']=='(냉)참조기']['1kg price'],china[china['species']=='(선)참조기']['1kg price']]

# %%
plt.boxplot(t)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20f1db2bbb0>,
#   <matplotlib.lines.Line2D at 0x20f1dbd10a0>,
#   <matplotlib.lines.Line2D at 0x20f1dbfe460>,
#   <matplotlib.lines.Line2D at 0x20f1dbfe730>,
#   <matplotlib.lines.Line2D at 0x20f1d7e6e50>,
#   <matplotlib.lines.Line2D at 0x20f1d7e6d90>,
#   <matplotlib.lines.Line2D at 0x20f7b8a3490>,
#   <matplotlib.lines.Line2D at 0x20f7b8a1580>],
#  'caps': [<matplotlib.lines.Line2D at 0x20f1dbd16d0>,
#   <matplotlib.lines.Line2D at 0x20f1dbd13a0>,
#   <matplotlib.lines.Line2D at 0x20f1dbfe970>,
#   <matplotlib.lines.Line2D at 0x20f76acc880>,
#   <matplotlib.lines.Line2D at 0x20f7b89f970>,
#   <matplotlib.lines.Line2D at 0x20f1b59edf0>,
#   <matplotlib.lines.Line2D at 0x20f1458fb20>,
#   <matplotlib.lines.Line2D at 0x20f1b592550>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20f1db2ba00>,
#   <matplotlib.lines.Line2D at 0x20f1dbfe220>,
#   <matplotlib.lines.Line2D at 0x20f1d7e6220>,
#   <matplotlib.lines.Line2D at 0x20f1b59e100>],
#  'medians': [<matplotlib.lines.Line2D at 0x20f1dbd1400>,
#   <matplotlib.lines.Line2D at 0x20f1d7e64c0>,
#   <matplotlib.lines.Line2D at 0x20f1b59eca0>,
#   <matplotlib.lines.Line2D at 0x20f0ed92670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20f1dbd1d00>,
#   <matplotlib.lines.Line2D at 0x20f1d7e6640>,
#   <matplotlib.lines.Line2D at 0x20f1b59ee50>,
#   <matplotlib.lines.Line2D at 0x20f14534190>],
#  'means': []}

# %%
# 참조기 / 조기 나눠서 다시 이상치 처리

# %%
pd.qcut(china['1kg price'], 4, ['q1','q2','q3','q4'])
# Out:
# 13       q4
# 24       q4
# 34       q4
# 44       q4
# 55       q4
#          ..
# 71357    q3
# 71386    q2
# 71417    q3
# 71426    q3
# 71447    q3
# Name: 1kg price, Length: 12626, dtype: category
# Categories (4, object): ['q1' < 'q2' < 'q3' < 'q4']

# %%
Q1 = (china['1kg price']).quantile(.25)
Q2 = (china['1kg price']).quantile(.5)
Q3 = (china['1kg price']).quantile(.75)
Q1,Q2,Q3
IQR = Q3-Q1
IQR
# Out:
# 6596.84

# %%
min = Q1-1.5*IQR
max = (Q3+1.5*IQR).round(2)
min, max
# Out:
# (-6978.59, 19408.77)

# %%
china = china[china['1kg price']<=max]

# %%
china
# Out:
#       species from        date      qty  1kg price  year month day
# 292    (냉)참조기   중국  2000.02.11  10160.0   14100.00  2000    02  11
# 712    (선)참조기   중국  2000.04.08    100.0   10000.00  2000    04  08
# 777    (선)참조기   중국  2000.04.18    210.0   16200.00  2000    04  18
# 787    (냉)참조기   중국  2000.04.19    100.0   15000.00  2000    04  19
# 826    (선)참조기   중국  2000.04.25    150.0   13300.00  2000    04  25
# ...       ...  ...         ...      ...        ...   ...   ...  ..
# 71357   (냉)조기   중국  2021.03.12     80.0    7150.00  2021    03  12
# 71386   (냉)조기   중국  2021.03.16    180.0    2972.22  2021    03  16
# 71417   (냉)조기   중국  2021.03.19     80.0    5675.00  2021    03  19
# 71426   (냉)조기   중국  2021.03.20    400.0    4775.00  2021    03  20
# 71447   (냉)조기   중국  2021.03.26    180.0    4777.78  2021    03  26
#
# [10642 rows x 8 columns]

# %%
origin
# Out:
#                 qty  1kg price
# species
# (냉)조기     3174057.3    5089.06
# (냉)조기 기타  3233507.4    4514.25
# (냉)참조기      72828.9   10202.62
# (선)참조기      31974.0   16347.46

# %%
china = china.drop(china[china['species']=='(선)참조기'].index,axis=0)

# %%
len(china[china['species']=='(냉)참조기'])
# Out:
# 270

# %%
china = china.drop(china[china['species']=='(냉)참조기'].index,axis=0)
china
# Out:
#       species from        date     qty  1kg price  year month day
# 9719    (냉)조기   중국  2006.03.22   320.0    2500.00  2006    03  22
# 9734    (냉)조기   중국  2006.03.28   800.0    1125.00  2006    03  28
# 9739    (냉)조기   중국  2006.03.30    80.0    8750.00  2006    03  30
# 9740    (냉)조기   중국  2006.03.30  1360.0    3375.00  2006    03  30
# 9741    (냉)조기   중국  2006.03.30   800.0    2250.00  2006    03  30
# ...       ...  ...         ...     ...        ...   ...   ...  ..
# 71357   (냉)조기   중국  2021.03.12    80.0    7150.00  2021    03  12
# 71386   (냉)조기   중국  2021.03.16   180.0    2972.22  2021    03  16
# 71417   (냉)조기   중국  2021.03.19    80.0    5675.00  2021    03  19
# 71426   (냉)조기   중국  2021.03.20   400.0    4775.00  2021    03  20
# 71447   (냉)조기   중국  2021.03.26   180.0    4777.78  2021    03  26
#
# [10313 rows x 8 columns]

# %%
# 국내 조기

# %%
china_exc
# Out:
#       species    from        date    qty  1kg price  year month day
# 7      (선)백조기      목포  2000.01.04    1.0    10000.0  2000    01  04
# 26     (선)백조기      목포  2000.01.06   30.0    17000.0  2000    01  06
# 35     (선)백조기      목포  2000.01.07    4.0     7500.0  2000    01  07
# 54     (선)참조기      목포  2000.01.08    1.0   150000.0  2000    01  08
# 56     (선)백조기      목포  2000.01.10    2.0    15000.0  2000    01  10
# ...       ...     ...         ...    ...        ...   ...   ...  ..
# 71477  (선)참조기     제주도  2021.03.31    2.1    65000.0  2021    03  31
# 71478  (선)백조기  부산(기장)  2021.04.01   40.0     4000.0  2021    04  01
# 71480  (선)참조기     제주도  2021.04.01    4.2    70000.0  2021    04  01
# 71481  (선)참조기     제주도  2021.04.01    6.8    70000.0  2021    04  01
# 71482  (선)참조기     제주도  2021.04.01  140.0    14835.0  2021    04  01
#
# [41590 rows x 8 columns]

# %%
grouped = china_exc.groupby('species')
origin = grouped.agg({'qty': 'sum', '1kg price' : 'mean'}).round(2)
origin
# Out:
#                qty  1kg price
# species
# (냉)조기     806038.5    3405.37
# (냉)참조기    572202.5    5005.90
# (선)백조기   1712176.9    2406.07
# (선)참조기   4760397.5    4493.58

# %%
china[['1kg price']].boxplot()
# Out:
# <AxesSubplot:>

# %%
pd.qcut(china['1kg price'], 4, ['q1','q2','q3','q4'])
Q1 = (china['1kg price']).quantile(.25)
Q2 = (china['1kg price']).quantile(.5)
Q3 = (china['1kg price']).quantile(.75)
Q1,Q2,Q3
IQR = Q3-Q1
IQR
# Out:
# 3211.54

# %%
min = Q1-1.5*IQR
max = (Q3+1.5*IQR).round(2)
min, max
# Out:
# (-2067.3099999999995, 10778.85)

# %%
china_exc=china_exc[china_exc['1kg price']<=max]

# %%
china_exc
# Out:
#       species    from        date    qty  1kg price  year month day
# 7      (선)백조기      목포  2000.01.04    1.0    10000.0  2000    01  04
# 35     (선)백조기      목포  2000.01.07    4.0     7500.0  2000    01  07
# 77     (선)백조기      목포  2000.01.13    3.0    10000.0  2000    01  13
# 85     (선)백조기      목포  2000.01.14    3.0     5000.0  2000    01  14
# 165    (선)백조기      목포  2000.01.25  103.0    10500.0  2000    01  25
# ...       ...     ...         ...    ...        ...   ...   ...  ..
# 71467  (선)백조기     제주도  2021.03.30   56.0     7125.0  2021    03  30
# 71469  (선)참조기     제주도  2021.03.30   80.0     7815.0  2021    03  30
# 71470  (선)백조기     제주도  2021.03.31   80.0     5312.5  2021    03  31
# 71471  (선)백조기     제주도  2021.03.31   40.0     1500.0  2021    03  31
# 71478  (선)백조기  부산(기장)  2021.04.01   40.0     4000.0  2021    04  01
#
# [35441 rows x 8 columns]

# %%
origin
# Out:
#                qty  1kg price
# species
# (냉)조기     806038.5    3405.37
# (냉)참조기    572202.5    5005.90
# (선)백조기   1712176.9    2406.07
# (선)참조기   4760397.5    4493.58

# %%
len(china_exc[china_exc['species']=='(냉)조기']), len(china_exc[china_exc['species']=='(냉)참조기']) , len(china_exc[china_exc['species']=='(선)백조기']) , len(china_exc[china_exc['species']=='(선)참조기'])
# Out:
# (1103, 1475, 21888, 10975)

# %%
china_exc = china_exc.drop(china_exc[china_exc['species']=='(냉)조기 기타'].index,axis=0)
china_exc
# Out:
#       species    from        date    qty  1kg price  year month day
# 7      (선)백조기      목포  2000.01.04    1.0    10000.0  2000    01  04
# 35     (선)백조기      목포  2000.01.07    4.0     7500.0  2000    01  07
# 77     (선)백조기      목포  2000.01.13    3.0    10000.0  2000    01  13
# 85     (선)백조기      목포  2000.01.14    3.0     5000.0  2000    01  14
# 165    (선)백조기      목포  2000.01.25  103.0    10500.0  2000    01  25
# ...       ...     ...         ...    ...        ...   ...   ...  ..
# 71467  (선)백조기     제주도  2021.03.30   56.0     7125.0  2021    03  30
# 71469  (선)참조기     제주도  2021.03.30   80.0     7815.0  2021    03  30
# 71470  (선)백조기     제주도  2021.03.31   80.0     5312.5  2021    03  31
# 71471  (선)백조기     제주도  2021.03.31   40.0     1500.0  2021    03  31
# 71478  (선)백조기  부산(기장)  2021.04.01   40.0     4000.0  2021    04  01
#
# [35441 rows x 8 columns]

# %%
plt.bar(origin.index,origin['qty'])
# Out:
# <BarContainer object of 4 artists>
